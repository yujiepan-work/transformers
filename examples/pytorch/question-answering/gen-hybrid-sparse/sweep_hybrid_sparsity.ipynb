# %%
import logging
import os
import random
import sys
from dataclasses import dataclass, field
from typing import Optional


import datasets
import numpy as np
from datasets import load_dataset, load_metric
from torch import embedding, embedding_bag

import transformers
from transformers import (
    AutoConfig,
    AutoModelForSequenceClassification,
    AutoModelForQuestionAnswering,
    AutoTokenizer,
    DataCollatorWithPadding,
    EvalPrediction,
    HfArgumentParser,
    PretrainedConfig,
    Trainer,
    TrainingArguments,
    default_data_collator,
    set_seed,
)
from transformers.trainer_utils import get_last_checkpoint
from transformers.utils import check_min_version
from transformers.utils.versions import require_version

from nncf.torch.nncf_network import NNCFNetwork
from nncf.torch.dynamic_graph.graph_tracer import create_input_infos, create_dummy_forward_fn
import torch.nn as nn

import pandas as pd
import numpy as np
import functools

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)
pd.set_option('display.float_format', '{:20,.2f}'.format)
pd.set_option('display.max_colwidth', None)

# %%
def show_full_df(x):
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', None)
    print(x)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')

# %%
def create_multiindex(list_of_string, level_delimiter="/"):
    def pad_tokenlist_to_depth(tokens, depth):
        gap = depth - len(tokens)
        tokens += [None] * gap
        return tokens
    
    list_of_tokenlist = list(map(lambda x: x.split(sep="/"), list_of_string))
    depth = max(map(len, list_of_tokenlist))
    mapfunc = functools.partial(pad_tokenlist_to_depth, depth=depth)
    equal_depth_tokenlist = list(map(mapfunc, list_of_tokenlist))
    midx = pd.MultiIndex.from_arrays(np.array(equal_depth_tokenlist).transpose())
    return midx

# %%
def analyze_module(module, input_, output, dict_to_save, module_node_name):
    def t2l(t):
        #tuple to list
        return list(t)

    def get_param(module):
        w_numel = None
        w_shape = None
        b_numel = None
        b_shape = None
        if hasattr(module, 'weight'):
            w_shape = t2l(module.weight.data.shape)
            w_numel = np.prod(w_shape)
        if hasattr(module, 'bias'):
            b_shape = t2l(module.bias.data.shape)
            b_numel = np.prod(b_shape)
        return {'weight_numel': w_numel, 
                'weight_shape': w_shape,
                'bias_numel': b_numel,
                'bias_shape': b_shape}

    def get_tensor_dim_size(t, prefix):
        return { 
            '{}_shape'.format(prefix): t2l(t.shape), 
            '{}_numel'.format(prefix): t.numel()
        }

    if isinstance(module, 
                    (nn.Conv1d, nn.ConvTranspose1d, 
                     nn.Conv2d, nn.ConvTranspose2d, 
                     nn.Conv3d, nn.ConvTranspose3d)):
        ks = module.weight.data.shape
        mac = np.prod(ks) * np.prod(output.shape[2:])
              
    elif isinstance(module, nn.Linear):
        if len(input_[0].shape) == 1:
            # In some test cases input tensor could have dimension [N]
            mac = input_[0].shape[0] * output.shape[-1]
        else:
            mac = np.prod(input_[0].shape[1:]) * output.shape[-1]

    elif isinstance(module, (nn.Embedding, nn.EmbeddingBag)):
        mac = 0

    else:
        return
    dict_to_save[module_node_name] = {}
    dict_to_save[module_node_name]['optype'] = module.__class__.__name__
    dict_to_save[module_node_name]['MAC'] = mac
    dict_to_save[module_node_name].update(get_param(module))
    dict_to_save[module_node_name].update(get_tensor_dim_size(input_[0], 'input'))
    dict_to_save[module_node_name].update(get_tensor_dim_size(output, 'output'))

    # dict_to_save[module_node_name]['param'] = get_param(module) 
    # dict_to_save[module_node_name]['input'] = get_tensor_dim_size(input_[0], 'input')
    # dict_to_save[module_node_name]['output'] = get_tensor_dim_size(output, 'output') 

def model_per_module_analysis(nncfnetwork):
    """
    Calculates FLOPS count for modules.
    """
    model = nncfnetwork
    flops_count_dict = {}

    def get_hook(name):
        return functools.partial(analyze_module, 
                                 dict_to_save=flops_count_dict,
                                 module_node_name=name)

    hook_list = []
    for nncf_node in model._original_graph.get_all_nodes():
        node_module = model.get_containing_module(nncf_node.node_name)
        if node_module is not None:
            hook_list.append(node_module.register_forward_hook(get_hook(nncf_node.node_name)))
        else:
            print("module is none for nncf node: {}".format(nncf_node.node_name))

    model.do_dummy_forward(force_eval=True)

    for h in hook_list:
        h.remove()
    return flops_count_dict

# %%
model_label = 'bert-large-uncased-whole-word-masking-finetuned-squad'

GLUE_TASKS = ["cola", "mnli", "mnli-mam", "mrpc", "qnli", "qqp", "rte", "sst2", "stsb", "wnli"]
task = "mnli"

# num_labels = 3 if task.startswith("mnli") else 1 if task=="stsb" else 2
model = AutoModelForQuestionAnswering.from_pretrained(model_label)
# , num_labels=num_labels)

# %%
batchsize = 1
seqlen = 384
input_cfg = {"input_info": [dict(sample_size=[batchsize, seqlen], type="long")]*3}
input_info_list = create_input_infos(input_cfg)
nncf_model = NNCFNetwork(model, input_info_list)
# Out:
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEmbeddings[embeddings]/Embedding[word_embeddings] by BertForQuestionAnswering/BertModel[bert]/BertEmbeddings[embeddings]/NNCFEmbedding[word_embeddings]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEmbeddings[embeddings]/Embedding[position_embeddings] by BertForQuestionAnswering/BertModel[bert]/BertEmbeddings[embeddings]/NNCFEmbedding[position_embeddings]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEmbeddings[embeddings]/Embedding[token_type_embeddings] by BertForQuestionAnswering/BertModel[bert]/BertEmbeddings[embeddings]/NNCFEmbedding[token_type_embeddings]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/Linear[query] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[query]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/Linear[key] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[key]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/Linear[value] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/NNCFLinear[value]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertIntermediate[intermediate]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertIntermediate[intermediate]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertOutput[output]/Linear[dense] by BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertOutput[output]/NNCFLinear[dense]
# INFO:nncf:Wrapping module BertForQuestionAnswering/Linear[qa_outputs] by BertForQuestionAnswering/NNCFLinear[qa_outputs]

# %%
d = model_per_module_analysis(nncf_model)
df = pd.DataFrame.from_dict(d, orient='index')
midx = create_multiindex(df.index.values.tolist())
df = df.set_index(midx)
# Out:
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[0]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[1]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[2]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[3]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[4]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[5]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[6]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[7]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[8]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[9]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[10]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[11]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[12]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[13]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[14]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[15]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[16]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[17]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[18]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[19]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[20]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[21]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[22]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0
# module is none for nncf node: BertForQuestionAnswering/BertModel[bert]/BertEncoder[encoder]/ModuleList[layer]/BertLayer[23]/BertAttention[attention]/BertSelfAttention[self]/Softmax/softmax_0

# %%
df
# Out:
#                                                                                                                                                                                                                         optype         MAC  weight_numel   weight_shape           bias_numel bias_shape     input_shape  input_numel    output_shape  output_numel
# BertForQuestionAnswering BertModel[bert]        BertEmbeddings[embeddings] NNCFEmbedding[word_embeddings]       embedding_0   NaN                            NaN                     NaN               NaN       NNCFEmbedding           0      31254528  [30522, 1024]                  NaN       None        [1, 384]          384  [1, 384, 1024]        393216
#                                                                            NNCFEmbedding[token_type_embeddings] embedding_0   NaN                            NaN                     NaN               NaN       NNCFEmbedding           0          2048      [2, 1024]                  NaN       None        [1, 384]          384  [1, 384, 1024]        393216
#                                                                            NNCFEmbedding[position_embeddings]   embedding_0   NaN                            NaN                     NaN               NaN       NNCFEmbedding           0        524288    [512, 1024]                  NaN       None        [1, 384]          384  [1, 384, 1024]        393216
#                                                 BertEncoder[encoder]       ModuleList[layer]                    BertLayer[0]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[1]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[2]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[3]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[4]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[5]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[6]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[7]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[8]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[9]  BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[10] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[11] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[12] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[13] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[14] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[15] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[16] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[17] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[18] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[19] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[20] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[21] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[22] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                                                                                                                 BertLayer[23] BertAttention[attention]       BertSelfAttention[self] NNCFLinear[query] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[key]   linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                                                      NNCFLinear[value] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                                                              BertSelfOutput[output]  NNCFLinear[dense] linear_0     NNCFLinear   402653184       1048576   [1024, 1024]             1,024.00     [1024]  [1, 384, 1024]       393216  [1, 384, 1024]        393216
#                                                                                                                               BertIntermediate[intermediate] NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [4096, 1024]             4,096.00     [4096]  [1, 384, 1024]       393216  [1, 384, 4096]       1572864
#                                                                                                                               BertOutput[output]             NNCFLinear[dense]       linear_0          NaN          NNCFLinear  1610612736       4194304   [1024, 4096]             1,024.00     [1024]  [1, 384, 4096]      1572864  [1, 384, 1024]        393216
#                          NNCFLinear[qa_outputs] linear_0                   NaN                                  NaN           NaN                            NaN                     NaN               NaN          NNCFLinear      786432          2048      [2, 1024]                 2.00        [2]  [1, 384, 1024]       393216     [1, 384, 2]           768

# %%
# df['flop']=df.MAC*2
# df['total_mem']=df.input_numel+df.weight_numel+df.output_numel
# df['ai'] = df['flop']/df['total_mem']
# df.loc[df.index[6:8]].set_index(pd.Index(['mhsa', 'ffnn']))

# %%
df_fc = df[df.optype == 'NNCFLinear'][:-1]

# %%
len(df_fc), len(df_fc)/6
# Out:
# (144, 24.0)

# %%
df_fc['weight_numel'].sum()
# Out:
# 301989888

# %%
(np.arange(16)+1) * 64
# Out:
# array([  64,  128,  192,  256,  320,  384,  448,  512,  576,  640,  704,
#         768,  832,  896,  960, 1024])

# %%
# Attention head
for seqlen in (np.arange(6)+1) *64:
    for headgroup in (np.arange(16)+1) * 64:
        print("sparsity: {:.3f} | nhead: {:5} | (seqlen:{:4}, {:4} :ncol/nrow)".format(1-headgroup/1024, headgroup/64, seqlen, headgroup))
        if (seqlen*headgroup % 4096) > 0:
            print("invalid (seqlen, nhead): ({}, {})".format(seqlen, headgroup/64))
# Out:
# sparsity: 0.938 | nhead:   1.0 | (seqlen:  64,   64 :ncol/nrow)
# sparsity: 0.875 | nhead:   2.0 | (seqlen:  64,  128 :ncol/nrow)
# sparsity: 0.812 | nhead:   3.0 | (seqlen:  64,  192 :ncol/nrow)
# sparsity: 0.750 | nhead:   4.0 | (seqlen:  64,  256 :ncol/nrow)
# sparsity: 0.688 | nhead:   5.0 | (seqlen:  64,  320 :ncol/nrow)
# sparsity: 0.625 | nhead:   6.0 | (seqlen:  64,  384 :ncol/nrow)
# sparsity: 0.562 | nhead:   7.0 | (seqlen:  64,  448 :ncol/nrow)
# sparsity: 0.500 | nhead:   8.0 | (seqlen:  64,  512 :ncol/nrow)
# sparsity: 0.438 | nhead:   9.0 | (seqlen:  64,  576 :ncol/nrow)
# sparsity: 0.375 | nhead:  10.0 | (seqlen:  64,  640 :ncol/nrow)
# sparsity: 0.312 | nhead:  11.0 | (seqlen:  64,  704 :ncol/nrow)
# sparsity: 0.250 | nhead:  12.0 | (seqlen:  64,  768 :ncol/nrow)
# sparsity: 0.188 | nhead:  13.0 | (seqlen:  64,  832 :ncol/nrow)
# sparsity: 0.125 | nhead:  14.0 | (seqlen:  64,  896 :ncol/nrow)
# sparsity: 0.062 | nhead:  15.0 | (seqlen:  64,  960 :ncol/nrow)
# sparsity: 0.000 | nhead:  16.0 | (seqlen:  64, 1024 :ncol/nrow)
# sparsity: 0.938 | nhead:   1.0 | (seqlen: 128,   64 :ncol/nrow)
# sparsity: 0.875 | nhead:   2.0 | (seqlen: 128,  128 :ncol/nrow)
# sparsity: 0.812 | nhead:   3.0 | (seqlen: 128,  192 :ncol/nrow)
# sparsity: 0.750 | nhead:   4.0 | (seqlen: 128,  256 :ncol/nrow)
# sparsity: 0.688 | nhead:   5.0 | (seqlen: 128,  320 :ncol/nrow)
# sparsity: 0.625 | nhead:   6.0 | (seqlen: 128,  384 :ncol/nrow)
# sparsity: 0.562 | nhead:   7.0 | (seqlen: 128,  448 :ncol/nrow)
# sparsity: 0.500 | nhead:   8.0 | (seqlen: 128,  512 :ncol/nrow)
# sparsity: 0.438 | nhead:   9.0 | (seqlen: 128,  576 :ncol/nrow)
# sparsity: 0.375 | nhead:  10.0 | (seqlen: 128,  640 :ncol/nrow)
# sparsity: 0.312 | nhead:  11.0 | (seqlen: 128,  704 :ncol/nrow)
# sparsity: 0.250 | nhead:  12.0 | (seqlen: 128,  768 :ncol/nrow)
# sparsity: 0.188 | nhead:  13.0 | (seqlen: 128,  832 :ncol/nrow)
# sparsity: 0.125 | nhead:  14.0 | (seqlen: 128,  896 :ncol/nrow)
# sparsity: 0.062 | nhead:  15.0 | (seqlen: 128,  960 :ncol/nrow)
# sparsity: 0.000 | nhead:  16.0 | (seqlen: 128, 1024 :ncol/nrow)
# sparsity: 0.938 | nhead:   1.0 | (seqlen: 192,   64 :ncol/nrow)
# sparsity: 0.875 | nhead:   2.0 | (seqlen: 192,  128 :ncol/nrow)
# sparsity: 0.812 | nhead:   3.0 | (seqlen: 192,  192 :ncol/nrow)
# sparsity: 0.750 | nhead:   4.0 | (seqlen: 192,  256 :ncol/nrow)
# sparsity: 0.688 | nhead:   5.0 | (seqlen: 192,  320 :ncol/nrow)
# sparsity: 0.625 | nhead:   6.0 | (seqlen: 192,  384 :ncol/nrow)
# sparsity: 0.562 | nhead:   7.0 | (seqlen: 192,  448 :ncol/nrow)
# sparsity: 0.500 | nhead:   8.0 | (seqlen: 192,  512 :ncol/nrow)
# sparsity: 0.438 | nhead:   9.0 | (seqlen: 192,  576 :ncol/nrow)
# sparsity: 0.375 | nhead:  10.0 | (seqlen: 192,  640 :ncol/nrow)
# sparsity: 0.312 | nhead:  11.0 | (seqlen: 192,  704 :ncol/nrow)
# sparsity: 0.250 | nhead:  12.0 | (seqlen: 192,  768 :ncol/nrow)
# sparsity: 0.188 | nhead:  13.0 | (seqlen: 192,  832 :ncol/nrow)
# sparsity: 0.125 | nhead:  14.0 | (seqlen: 192,  896 :ncol/nrow)
# sparsity: 0.062 | nhead:  15.0 | (seqlen: 192,  960 :ncol/nrow)
# sparsity: 0.000 | nhead:  16.0 | (seqlen: 192, 1024 :ncol/nrow)
# sparsity: 0.938 | nhead:   1.0 | (seqlen: 256,   64 :ncol/nrow)
# sparsity: 0.875 | nhead:   2.0 | (seqlen: 256,  128 :ncol/nrow)
# sparsity: 0.812 | nhead:   3.0 | (seqlen: 256,  192 :ncol/nrow)
# sparsity: 0.750 | nhead:   4.0 | (seqlen: 256,  256 :ncol/nrow)
# sparsity: 0.688 | nhead:   5.0 | (seqlen: 256,  320 :ncol/nrow)
# sparsity: 0.625 | nhead:   6.0 | (seqlen: 256,  384 :ncol/nrow)
# sparsity: 0.562 | nhead:   7.0 | (seqlen: 256,  448 :ncol/nrow)
# sparsity: 0.500 | nhead:   8.0 | (seqlen: 256,  512 :ncol/nrow)
# sparsity: 0.438 | nhead:   9.0 | (seqlen: 256,  576 :ncol/nrow)
# sparsity: 0.375 | nhead:  10.0 | (seqlen: 256,  640 :ncol/nrow)
# sparsity: 0.312 | nhead:  11.0 | (seqlen: 256,  704 :ncol/nrow)
# sparsity: 0.250 | nhead:  12.0 | (seqlen: 256,  768 :ncol/nrow)
# sparsity: 0.188 | nhead:  13.0 | (seqlen: 256,  832 :ncol/nrow)
# sparsity: 0.125 | nhead:  14.0 | (seqlen: 256,  896 :ncol/nrow)
# sparsity: 0.062 | nhead:  15.0 | (seqlen: 256,  960 :ncol/nrow)
# sparsity: 0.000 | nhead:  16.0 | (seqlen: 256, 1024 :ncol/nrow)
# sparsity: 0.938 | nhead:   1.0 | (seqlen: 320,   64 :ncol/nrow)
# sparsity: 0.875 | nhead:   2.0 | (seqlen: 320,  128 :ncol/nrow)
# sparsity: 0.812 | nhead:   3.0 | (seqlen: 320,  192 :ncol/nrow)
# sparsity: 0.750 | nhead:   4.0 | (seqlen: 320,  256 :ncol/nrow)
# sparsity: 0.688 | nhead:   5.0 | (seqlen: 320,  320 :ncol/nrow)
# sparsity: 0.625 | nhead:   6.0 | (seqlen: 320,  384 :ncol/nrow)
# sparsity: 0.562 | nhead:   7.0 | (seqlen: 320,  448 :ncol/nrow)
# sparsity: 0.500 | nhead:   8.0 | (seqlen: 320,  512 :ncol/nrow)
# sparsity: 0.438 | nhead:   9.0 | (seqlen: 320,  576 :ncol/nrow)
# sparsity: 0.375 | nhead:  10.0 | (seqlen: 320,  640 :ncol/nrow)
# sparsity: 0.312 | nhead:  11.0 | (seqlen: 320,  704 :ncol/nrow)
# sparsity: 0.250 | nhead:  12.0 | (seqlen: 320,  768 :ncol/nrow)
# sparsity: 0.188 | nhead:  13.0 | (seqlen: 320,  832 :ncol/nrow)
# sparsity: 0.125 | nhead:  14.0 | (seqlen: 320,  896 :ncol/nrow)
# sparsity: 0.062 | nhead:  15.0 | (seqlen: 320,  960 :ncol/nrow)
# sparsity: 0.000 | nhead:  16.0 | (seqlen: 320, 1024 :ncol/nrow)
# sparsity: 0.938 | nhead:   1.0 | (seqlen: 384,   64 :ncol/nrow)
# sparsity: 0.875 | nhead:   2.0 | (seqlen: 384,  128 :ncol/nrow)
# sparsity: 0.812 | nhead:   3.0 | (seqlen: 384,  192 :ncol/nrow)
# sparsity: 0.750 | nhead:   4.0 | (seqlen: 384,  256 :ncol/nrow)
# sparsity: 0.688 | nhead:   5.0 | (seqlen: 384,  320 :ncol/nrow)
# sparsity: 0.625 | nhead:   6.0 | (seqlen: 384,  384 :ncol/nrow)
# sparsity: 0.562 | nhead:   7.0 | (seqlen: 384,  448 :ncol/nrow)
# sparsity: 0.500 | nhead:   8.0 | (seqlen: 384,  512 :ncol/nrow)
# sparsity: 0.438 | nhead:   9.0 | (seqlen: 384,  576 :ncol/nrow)
# sparsity: 0.375 | nhead:  10.0 | (seqlen: 384,  640 :ncol/nrow)
# sparsity: 0.312 | nhead:  11.0 | (seqlen: 384,  704 :ncol/nrow)
# sparsity: 0.250 | nhead:  12.0 | (seqlen: 384,  768 :ncol/nrow)
# sparsity: 0.188 | nhead:  13.0 | (seqlen: 384,  832 :ncol/nrow)
# sparsity: 0.125 | nhead:  14.0 | (seqlen: 384,  896 :ncol/nrow)
# sparsity: 0.062 | nhead:  15.0 | (seqlen: 384,  960 :ncol/nrow)
# sparsity: 0.000 | nhead:  16.0 | (seqlen: 384, 1024 :ncol/nrow)

# %%
# FFNN
for seqlen in (np.arange(6)+1) *64:
    for ffnn_dim in (np.arange(4096)+1):
        if (seqlen*ffnn_dim % 4096) == 0:
            # print("(seqlen:{:4}, {:4} :ncol/nrow)".format(seqlen, ffnn_dim))
            print("sparsity: {:.3f} | ffnn: {:5} | (seqlen:{:4}, {:4} :ncol/nrow)".format(1-ffnn_dim/4096, ffnn_dim, seqlen, ffnn_dim))
# Out:
# sparsity: 0.984 | ffnn:    64 | (seqlen:  64,   64 :ncol/nrow)
# sparsity: 0.969 | ffnn:   128 | (seqlen:  64,  128 :ncol/nrow)
# sparsity: 0.953 | ffnn:   192 | (seqlen:  64,  192 :ncol/nrow)
# sparsity: 0.938 | ffnn:   256 | (seqlen:  64,  256 :ncol/nrow)
# sparsity: 0.922 | ffnn:   320 | (seqlen:  64,  320 :ncol/nrow)
# sparsity: 0.906 | ffnn:   384 | (seqlen:  64,  384 :ncol/nrow)
# sparsity: 0.891 | ffnn:   448 | (seqlen:  64,  448 :ncol/nrow)
# sparsity: 0.875 | ffnn:   512 | (seqlen:  64,  512 :ncol/nrow)
# sparsity: 0.859 | ffnn:   576 | (seqlen:  64,  576 :ncol/nrow)
# sparsity: 0.844 | ffnn:   640 | (seqlen:  64,  640 :ncol/nrow)
# sparsity: 0.828 | ffnn:   704 | (seqlen:  64,  704 :ncol/nrow)
# sparsity: 0.812 | ffnn:   768 | (seqlen:  64,  768 :ncol/nrow)
# sparsity: 0.797 | ffnn:   832 | (seqlen:  64,  832 :ncol/nrow)
# sparsity: 0.781 | ffnn:   896 | (seqlen:  64,  896 :ncol/nrow)
# sparsity: 0.766 | ffnn:   960 | (seqlen:  64,  960 :ncol/nrow)
# sparsity: 0.750 | ffnn:  1024 | (seqlen:  64, 1024 :ncol/nrow)
# sparsity: 0.734 | ffnn:  1088 | (seqlen:  64, 1088 :ncol/nrow)
# sparsity: 0.719 | ffnn:  1152 | (seqlen:  64, 1152 :ncol/nrow)
# sparsity: 0.703 | ffnn:  1216 | (seqlen:  64, 1216 :ncol/nrow)
# sparsity: 0.688 | ffnn:  1280 | (seqlen:  64, 1280 :ncol/nrow)
# sparsity: 0.672 | ffnn:  1344 | (seqlen:  64, 1344 :ncol/nrow)
# sparsity: 0.656 | ffnn:  1408 | (seqlen:  64, 1408 :ncol/nrow)
# sparsity: 0.641 | ffnn:  1472 | (seqlen:  64, 1472 :ncol/nrow)
# sparsity: 0.625 | ffnn:  1536 | (seqlen:  64, 1536 :ncol/nrow)
# sparsity: 0.609 | ffnn:  1600 | (seqlen:  64, 1600 :ncol/nrow)
# sparsity: 0.594 | ffnn:  1664 | (seqlen:  64, 1664 :ncol/nrow)
# sparsity: 0.578 | ffnn:  1728 | (seqlen:  64, 1728 :ncol/nrow)
# sparsity: 0.562 | ffnn:  1792 | (seqlen:  64, 1792 :ncol/nrow)
# sparsity: 0.547 | ffnn:  1856 | (seqlen:  64, 1856 :ncol/nrow)
# sparsity: 0.531 | ffnn:  1920 | (seqlen:  64, 1920 :ncol/nrow)
# sparsity: 0.516 | ffnn:  1984 | (seqlen:  64, 1984 :ncol/nrow)
# sparsity: 0.500 | ffnn:  2048 | (seqlen:  64, 2048 :ncol/nrow)
# sparsity: 0.484 | ffnn:  2112 | (seqlen:  64, 2112 :ncol/nrow)
# sparsity: 0.469 | ffnn:  2176 | (seqlen:  64, 2176 :ncol/nrow)
# sparsity: 0.453 | ffnn:  2240 | (seqlen:  64, 2240 :ncol/nrow)
# sparsity: 0.438 | ffnn:  2304 | (seqlen:  64, 2304 :ncol/nrow)
# sparsity: 0.422 | ffnn:  2368 | (seqlen:  64, 2368 :ncol/nrow)
# sparsity: 0.406 | ffnn:  2432 | (seqlen:  64, 2432 :ncol/nrow)
# sparsity: 0.391 | ffnn:  2496 | (seqlen:  64, 2496 :ncol/nrow)
# sparsity: 0.375 | ffnn:  2560 | (seqlen:  64, 2560 :ncol/nrow)
# sparsity: 0.359 | ffnn:  2624 | (seqlen:  64, 2624 :ncol/nrow)
# sparsity: 0.344 | ffnn:  2688 | (seqlen:  64, 2688 :ncol/nrow)
# sparsity: 0.328 | ffnn:  2752 | (seqlen:  64, 2752 :ncol/nrow)
# sparsity: 0.312 | ffnn:  2816 | (seqlen:  64, 2816 :ncol/nrow)
# sparsity: 0.297 | ffnn:  2880 | (seqlen:  64, 2880 :ncol/nrow)
# sparsity: 0.281 | ffnn:  2944 | (seqlen:  64, 2944 :ncol/nrow)
# sparsity: 0.266 | ffnn:  3008 | (seqlen:  64, 3008 :ncol/nrow)
# sparsity: 0.250 | ffnn:  3072 | (seqlen:  64, 3072 :ncol/nrow)
# sparsity: 0.234 | ffnn:  3136 | (seqlen:  64, 3136 :ncol/nrow)
# sparsity: 0.219 | ffnn:  3200 | (seqlen:  64, 3200 :ncol/nrow)
# sparsity: 0.203 | ffnn:  3264 | (seqlen:  64, 3264 :ncol/nrow)
# sparsity: 0.188 | ffnn:  3328 | (seqlen:  64, 3328 :ncol/nrow)
# sparsity: 0.172 | ffnn:  3392 | (seqlen:  64, 3392 :ncol/nrow)
# sparsity: 0.156 | ffnn:  3456 | (seqlen:  64, 3456 :ncol/nrow)
# sparsity: 0.141 | ffnn:  3520 | (seqlen:  64, 3520 :ncol/nrow)
# sparsity: 0.125 | ffnn:  3584 | (seqlen:  64, 3584 :ncol/nrow)
# sparsity: 0.109 | ffnn:  3648 | (seqlen:  64, 3648 :ncol/nrow)
# sparsity: 0.094 | ffnn:  3712 | (seqlen:  64, 3712 :ncol/nrow)
# sparsity: 0.078 | ffnn:  3776 | (seqlen:  64, 3776 :ncol/nrow)
# sparsity: 0.062 | ffnn:  3840 | (seqlen:  64, 3840 :ncol/nrow)
# sparsity: 0.047 | ffnn:  3904 | (seqlen:  64, 3904 :ncol/nrow)
# sparsity: 0.031 | ffnn:  3968 | (seqlen:  64, 3968 :ncol/nrow)
# sparsity: 0.016 | ffnn:  4032 | (seqlen:  64, 4032 :ncol/nrow)
# sparsity: 0.000 | ffnn:  4096 | (seqlen:  64, 4096 :ncol/nrow)
# sparsity: 0.992 | ffnn:    32 | (seqlen: 128,   32 :ncol/nrow)
# sparsity: 0.984 | ffnn:    64 | (seqlen: 128,   64 :ncol/nrow)
# sparsity: 0.977 | ffnn:    96 | (seqlen: 128,   96 :ncol/nrow)
# sparsity: 0.969 | ffnn:   128 | (seqlen: 128,  128 :ncol/nrow)
# sparsity: 0.961 | ffnn:   160 | (seqlen: 128,  160 :ncol/nrow)
# sparsity: 0.953 | ffnn:   192 | (seqlen: 128,  192 :ncol/nrow)
# sparsity: 0.945 | ffnn:   224 | (seqlen: 128,  224 :ncol/nrow)
# sparsity: 0.938 | ffnn:   256 | (seqlen: 128,  256 :ncol/nrow)
# sparsity: 0.930 | ffnn:   288 | (seqlen: 128,  288 :ncol/nrow)
# sparsity: 0.922 | ffnn:   320 | (seqlen: 128,  320 :ncol/nrow)
# sparsity: 0.914 | ffnn:   352 | (seqlen: 128,  352 :ncol/nrow)
# sparsity: 0.906 | ffnn:   384 | (seqlen: 128,  384 :ncol/nrow)
# sparsity: 0.898 | ffnn:   416 | (seqlen: 128,  416 :ncol/nrow)
# sparsity: 0.891 | ffnn:   448 | (seqlen: 128,  448 :ncol/nrow)
# sparsity: 0.883 | ffnn:   480 | (seqlen: 128,  480 :ncol/nrow)
# sparsity: 0.875 | ffnn:   512 | (seqlen: 128,  512 :ncol/nrow)
# sparsity: 0.867 | ffnn:   544 | (seqlen: 128,  544 :ncol/nrow)
# sparsity: 0.859 | ffnn:   576 | (seqlen: 128,  576 :ncol/nrow)
# sparsity: 0.852 | ffnn:   608 | (seqlen: 128,  608 :ncol/nrow)
# sparsity: 0.844 | ffnn:   640 | (seqlen: 128,  640 :ncol/nrow)
# sparsity: 0.836 | ffnn:   672 | (seqlen: 128,  672 :ncol/nrow)
# sparsity: 0.828 | ffnn:   704 | (seqlen: 128,  704 :ncol/nrow)
# sparsity: 0.820 | ffnn:   736 | (seqlen: 128,  736 :ncol/nrow)
# sparsity: 0.812 | ffnn:   768 | (seqlen: 128,  768 :ncol/nrow)
# sparsity: 0.805 | ffnn:   800 | (seqlen: 128,  800 :ncol/nrow)
# sparsity: 0.797 | ffnn:   832 | (seqlen: 128,  832 :ncol/nrow)
# sparsity: 0.789 | ffnn:   864 | (seqlen: 128,  864 :ncol/nrow)
# sparsity: 0.781 | ffnn:   896 | (seqlen: 128,  896 :ncol/nrow)
# sparsity: 0.773 | ffnn:   928 | (seqlen: 128,  928 :ncol/nrow)
# sparsity: 0.766 | ffnn:   960 | (seqlen: 128,  960 :ncol/nrow)
# sparsity: 0.758 | ffnn:   992 | (seqlen: 128,  992 :ncol/nrow)
# sparsity: 0.750 | ffnn:  1024 | (seqlen: 128, 1024 :ncol/nrow)
# sparsity: 0.742 | ffnn:  1056 | (seqlen: 128, 1056 :ncol/nrow)
# sparsity: 0.734 | ffnn:  1088 | (seqlen: 128, 1088 :ncol/nrow)
# sparsity: 0.727 | ffnn:  1120 | (seqlen: 128, 1120 :ncol/nrow)
# sparsity: 0.719 | ffnn:  1152 | (seqlen: 128, 1152 :ncol/nrow)
# sparsity: 0.711 | ffnn:  1184 | (seqlen: 128, 1184 :ncol/nrow)
# sparsity: 0.703 | ffnn:  1216 | (seqlen: 128, 1216 :ncol/nrow)
# sparsity: 0.695 | ffnn:  1248 | (seqlen: 128, 1248 :ncol/nrow)
# sparsity: 0.688 | ffnn:  1280 | (seqlen: 128, 1280 :ncol/nrow)
# sparsity: 0.680 | ffnn:  1312 | (seqlen: 128, 1312 :ncol/nrow)
# sparsity: 0.672 | ffnn:  1344 | (seqlen: 128, 1344 :ncol/nrow)
# sparsity: 0.664 | ffnn:  1376 | (seqlen: 128, 1376 :ncol/nrow)
# sparsity: 0.656 | ffnn:  1408 | (seqlen: 128, 1408 :ncol/nrow)
# sparsity: 0.648 | ffnn:  1440 | (seqlen: 128, 1440 :ncol/nrow)
# sparsity: 0.641 | ffnn:  1472 | (seqlen: 128, 1472 :ncol/nrow)
# sparsity: 0.633 | ffnn:  1504 | (seqlen: 128, 1504 :ncol/nrow)
# sparsity: 0.625 | ffnn:  1536 | (seqlen: 128, 1536 :ncol/nrow)
# sparsity: 0.617 | ffnn:  1568 | (seqlen: 128, 1568 :ncol/nrow)
# sparsity: 0.609 | ffnn:  1600 | (seqlen: 128, 1600 :ncol/nrow)
# sparsity: 0.602 | ffnn:  1632 | (seqlen: 128, 1632 :ncol/nrow)
# sparsity: 0.594 | ffnn:  1664 | (seqlen: 128, 1664 :ncol/nrow)
# sparsity: 0.586 | ffnn:  1696 | (seqlen: 128, 1696 :ncol/nrow)
# sparsity: 0.578 | ffnn:  1728 | (seqlen: 128, 1728 :ncol/nrow)
# sparsity: 0.570 | ffnn:  1760 | (seqlen: 128, 1760 :ncol/nrow)
# sparsity: 0.562 | ffnn:  1792 | (seqlen: 128, 1792 :ncol/nrow)
# sparsity: 0.555 | ffnn:  1824 | (seqlen: 128, 1824 :ncol/nrow)
# sparsity: 0.547 | ffnn:  1856 | (seqlen: 128, 1856 :ncol/nrow)
# sparsity: 0.539 | ffnn:  1888 | (seqlen: 128, 1888 :ncol/nrow)
# sparsity: 0.531 | ffnn:  1920 | (seqlen: 128, 1920 :ncol/nrow)
# sparsity: 0.523 | ffnn:  1952 | (seqlen: 128, 1952 :ncol/nrow)
# sparsity: 0.516 | ffnn:  1984 | (seqlen: 128, 1984 :ncol/nrow)
# sparsity: 0.508 | ffnn:  2016 | (seqlen: 128, 2016 :ncol/nrow)
# sparsity: 0.500 | ffnn:  2048 | (seqlen: 128, 2048 :ncol/nrow)
# sparsity: 0.492 | ffnn:  2080 | (seqlen: 128, 2080 :ncol/nrow)
# sparsity: 0.484 | ffnn:  2112 | (seqlen: 128, 2112 :ncol/nrow)
# sparsity: 0.477 | ffnn:  2144 | (seqlen: 128, 2144 :ncol/nrow)
# sparsity: 0.469 | ffnn:  2176 | (seqlen: 128, 2176 :ncol/nrow)
# sparsity: 0.461 | ffnn:  2208 | (seqlen: 128, 2208 :ncol/nrow)
# sparsity: 0.453 | ffnn:  2240 | (seqlen: 128, 2240 :ncol/nrow)
# sparsity: 0.445 | ffnn:  2272 | (seqlen: 128, 2272 :ncol/nrow)
# sparsity: 0.438 | ffnn:  2304 | (seqlen: 128, 2304 :ncol/nrow)
# sparsity: 0.430 | ffnn:  2336 | (seqlen: 128, 2336 :ncol/nrow)
# sparsity: 0.422 | ffnn:  2368 | (seqlen: 128, 2368 :ncol/nrow)
# sparsity: 0.414 | ffnn:  2400 | (seqlen: 128, 2400 :ncol/nrow)
# sparsity: 0.406 | ffnn:  2432 | (seqlen: 128, 2432 :ncol/nrow)
# sparsity: 0.398 | ffnn:  2464 | (seqlen: 128, 2464 :ncol/nrow)
# sparsity: 0.391 | ffnn:  2496 | (seqlen: 128, 2496 :ncol/nrow)
# sparsity: 0.383 | ffnn:  2528 | (seqlen: 128, 2528 :ncol/nrow)
# sparsity: 0.375 | ffnn:  2560 | (seqlen: 128, 2560 :ncol/nrow)
# sparsity: 0.367 | ffnn:  2592 | (seqlen: 128, 2592 :ncol/nrow)
# sparsity: 0.359 | ffnn:  2624 | (seqlen: 128, 2624 :ncol/nrow)
# sparsity: 0.352 | ffnn:  2656 | (seqlen: 128, 2656 :ncol/nrow)
# sparsity: 0.344 | ffnn:  2688 | (seqlen: 128, 2688 :ncol/nrow)
# sparsity: 0.336 | ffnn:  2720 | (seqlen: 128, 2720 :ncol/nrow)
# sparsity: 0.328 | ffnn:  2752 | (seqlen: 128, 2752 :ncol/nrow)
# sparsity: 0.320 | ffnn:  2784 | (seqlen: 128, 2784 :ncol/nrow)
# sparsity: 0.312 | ffnn:  2816 | (seqlen: 128, 2816 :ncol/nrow)
# sparsity: 0.305 | ffnn:  2848 | (seqlen: 128, 2848 :ncol/nrow)
# sparsity: 0.297 | ffnn:  2880 | (seqlen: 128, 2880 :ncol/nrow)
# sparsity: 0.289 | ffnn:  2912 | (seqlen: 128, 2912 :ncol/nrow)
# sparsity: 0.281 | ffnn:  2944 | (seqlen: 128, 2944 :ncol/nrow)
# sparsity: 0.273 | ffnn:  2976 | (seqlen: 128, 2976 :ncol/nrow)
# sparsity: 0.266 | ffnn:  3008 | (seqlen: 128, 3008 :ncol/nrow)
# sparsity: 0.258 | ffnn:  3040 | (seqlen: 128, 3040 :ncol/nrow)
# sparsity: 0.250 | ffnn:  3072 | (seqlen: 128, 3072 :ncol/nrow)
# sparsity: 0.242 | ffnn:  3104 | (seqlen: 128, 3104 :ncol/nrow)
# sparsity: 0.234 | ffnn:  3136 | (seqlen: 128, 3136 :ncol/nrow)
# sparsity: 0.227 | ffnn:  3168 | (seqlen: 128, 3168 :ncol/nrow)
# sparsity: 0.219 | ffnn:  3200 | (seqlen: 128, 3200 :ncol/nrow)
# sparsity: 0.211 | ffnn:  3232 | (seqlen: 128, 3232 :ncol/nrow)
# sparsity: 0.203 | ffnn:  3264 | (seqlen: 128, 3264 :ncol/nrow)
# sparsity: 0.195 | ffnn:  3296 | (seqlen: 128, 3296 :ncol/nrow)
# sparsity: 0.188 | ffnn:  3328 | (seqlen: 128, 3328 :ncol/nrow)
# sparsity: 0.180 | ffnn:  3360 | (seqlen: 128, 3360 :ncol/nrow)
# sparsity: 0.172 | ffnn:  3392 | (seqlen: 128, 3392 :ncol/nrow)
# sparsity: 0.164 | ffnn:  3424 | (seqlen: 128, 3424 :ncol/nrow)
# sparsity: 0.156 | ffnn:  3456 | (seqlen: 128, 3456 :ncol/nrow)
# sparsity: 0.148 | ffnn:  3488 | (seqlen: 128, 3488 :ncol/nrow)
# sparsity: 0.141 | ffnn:  3520 | (seqlen: 128, 3520 :ncol/nrow)
# sparsity: 0.133 | ffnn:  3552 | (seqlen: 128, 3552 :ncol/nrow)
# sparsity: 0.125 | ffnn:  3584 | (seqlen: 128, 3584 :ncol/nrow)
# sparsity: 0.117 | ffnn:  3616 | (seqlen: 128, 3616 :ncol/nrow)
# sparsity: 0.109 | ffnn:  3648 | (seqlen: 128, 3648 :ncol/nrow)
# sparsity: 0.102 | ffnn:  3680 | (seqlen: 128, 3680 :ncol/nrow)
# sparsity: 0.094 | ffnn:  3712 | (seqlen: 128, 3712 :ncol/nrow)
# sparsity: 0.086 | ffnn:  3744 | (seqlen: 128, 3744 :ncol/nrow)
# sparsity: 0.078 | ffnn:  3776 | (seqlen: 128, 3776 :ncol/nrow)
# sparsity: 0.070 | ffnn:  3808 | (seqlen: 128, 3808 :ncol/nrow)
# sparsity: 0.062 | ffnn:  3840 | (seqlen: 128, 3840 :ncol/nrow)
# sparsity: 0.055 | ffnn:  3872 | (seqlen: 128, 3872 :ncol/nrow)
# sparsity: 0.047 | ffnn:  3904 | (seqlen: 128, 3904 :ncol/nrow)
# sparsity: 0.039 | ffnn:  3936 | (seqlen: 128, 3936 :ncol/nrow)
# sparsity: 0.031 | ffnn:  3968 | (seqlen: 128, 3968 :ncol/nrow)
# sparsity: 0.023 | ffnn:  4000 | (seqlen: 128, 4000 :ncol/nrow)
# sparsity: 0.016 | ffnn:  4032 | (seqlen: 128, 4032 :ncol/nrow)
# sparsity: 0.008 | ffnn:  4064 | (seqlen: 128, 4064 :ncol/nrow)
# sparsity: 0.000 | ffnn:  4096 | (seqlen: 128, 4096 :ncol/nrow)
# sparsity: 0.984 | ffnn:    64 | (seqlen: 192,   64 :ncol/nrow)
# sparsity: 0.969 | ffnn:   128 | (seqlen: 192,  128 :ncol/nrow)
# sparsity: 0.953 | ffnn:   192 | (seqlen: 192,  192 :ncol/nrow)
# sparsity: 0.938 | ffnn:   256 | (seqlen: 192,  256 :ncol/nrow)
# sparsity: 0.922 | ffnn:   320 | (seqlen: 192,  320 :ncol/nrow)
# sparsity: 0.906 | ffnn:   384 | (seqlen: 192,  384 :ncol/nrow)
# sparsity: 0.891 | ffnn:   448 | (seqlen: 192,  448 :ncol/nrow)
# sparsity: 0.875 | ffnn:   512 | (seqlen: 192,  512 :ncol/nrow)
# sparsity: 0.859 | ffnn:   576 | (seqlen: 192,  576 :ncol/nrow)
# sparsity: 0.844 | ffnn:   640 | (seqlen: 192,  640 :ncol/nrow)
# sparsity: 0.828 | ffnn:   704 | (seqlen: 192,  704 :ncol/nrow)
# sparsity: 0.812 | ffnn:   768 | (seqlen: 192,  768 :ncol/nrow)
# sparsity: 0.797 | ffnn:   832 | (seqlen: 192,  832 :ncol/nrow)
# sparsity: 0.781 | ffnn:   896 | (seqlen: 192,  896 :ncol/nrow)
# sparsity: 0.766 | ffnn:   960 | (seqlen: 192,  960 :ncol/nrow)
# sparsity: 0.750 | ffnn:  1024 | (seqlen: 192, 1024 :ncol/nrow)
# sparsity: 0.734 | ffnn:  1088 | (seqlen: 192, 1088 :ncol/nrow)
# sparsity: 0.719 | ffnn:  1152 | (seqlen: 192, 1152 :ncol/nrow)
# sparsity: 0.703 | ffnn:  1216 | (seqlen: 192, 1216 :ncol/nrow)
# sparsity: 0.688 | ffnn:  1280 | (seqlen: 192, 1280 :ncol/nrow)
# sparsity: 0.672 | ffnn:  1344 | (seqlen: 192, 1344 :ncol/nrow)
# sparsity: 0.656 | ffnn:  1408 | (seqlen: 192, 1408 :ncol/nrow)
# sparsity: 0.641 | ffnn:  1472 | (seqlen: 192, 1472 :ncol/nrow)
# sparsity: 0.625 | ffnn:  1536 | (seqlen: 192, 1536 :ncol/nrow)
# sparsity: 0.609 | ffnn:  1600 | (seqlen: 192, 1600 :ncol/nrow)
# sparsity: 0.594 | ffnn:  1664 | (seqlen: 192, 1664 :ncol/nrow)
# sparsity: 0.578 | ffnn:  1728 | (seqlen: 192, 1728 :ncol/nrow)
# sparsity: 0.562 | ffnn:  1792 | (seqlen: 192, 1792 :ncol/nrow)
# sparsity: 0.547 | ffnn:  1856 | (seqlen: 192, 1856 :ncol/nrow)
# sparsity: 0.531 | ffnn:  1920 | (seqlen: 192, 1920 :ncol/nrow)
# sparsity: 0.516 | ffnn:  1984 | (seqlen: 192, 1984 :ncol/nrow)
# sparsity: 0.500 | ffnn:  2048 | (seqlen: 192, 2048 :ncol/nrow)
# sparsity: 0.484 | ffnn:  2112 | (seqlen: 192, 2112 :ncol/nrow)
# sparsity: 0.469 | ffnn:  2176 | (seqlen: 192, 2176 :ncol/nrow)
# sparsity: 0.453 | ffnn:  2240 | (seqlen: 192, 2240 :ncol/nrow)
# sparsity: 0.438 | ffnn:  2304 | (seqlen: 192, 2304 :ncol/nrow)
# sparsity: 0.422 | ffnn:  2368 | (seqlen: 192, 2368 :ncol/nrow)
# sparsity: 0.406 | ffnn:  2432 | (seqlen: 192, 2432 :ncol/nrow)
# sparsity: 0.391 | ffnn:  2496 | (seqlen: 192, 2496 :ncol/nrow)
# sparsity: 0.375 | ffnn:  2560 | (seqlen: 192, 2560 :ncol/nrow)
# sparsity: 0.359 | ffnn:  2624 | (seqlen: 192, 2624 :ncol/nrow)
# sparsity: 0.344 | ffnn:  2688 | (seqlen: 192, 2688 :ncol/nrow)
# sparsity: 0.328 | ffnn:  2752 | (seqlen: 192, 2752 :ncol/nrow)
# sparsity: 0.312 | ffnn:  2816 | (seqlen: 192, 2816 :ncol/nrow)
# sparsity: 0.297 | ffnn:  2880 | (seqlen: 192, 2880 :ncol/nrow)
# sparsity: 0.281 | ffnn:  2944 | (seqlen: 192, 2944 :ncol/nrow)
# sparsity: 0.266 | ffnn:  3008 | (seqlen: 192, 3008 :ncol/nrow)
# sparsity: 0.250 | ffnn:  3072 | (seqlen: 192, 3072 :ncol/nrow)
# sparsity: 0.234 | ffnn:  3136 | (seqlen: 192, 3136 :ncol/nrow)
# sparsity: 0.219 | ffnn:  3200 | (seqlen: 192, 3200 :ncol/nrow)
# sparsity: 0.203 | ffnn:  3264 | (seqlen: 192, 3264 :ncol/nrow)
# sparsity: 0.188 | ffnn:  3328 | (seqlen: 192, 3328 :ncol/nrow)
# sparsity: 0.172 | ffnn:  3392 | (seqlen: 192, 3392 :ncol/nrow)
# sparsity: 0.156 | ffnn:  3456 | (seqlen: 192, 3456 :ncol/nrow)
# sparsity: 0.141 | ffnn:  3520 | (seqlen: 192, 3520 :ncol/nrow)
# sparsity: 0.125 | ffnn:  3584 | (seqlen: 192, 3584 :ncol/nrow)
# sparsity: 0.109 | ffnn:  3648 | (seqlen: 192, 3648 :ncol/nrow)
# sparsity: 0.094 | ffnn:  3712 | (seqlen: 192, 3712 :ncol/nrow)
# sparsity: 0.078 | ffnn:  3776 | (seqlen: 192, 3776 :ncol/nrow)
# sparsity: 0.062 | ffnn:  3840 | (seqlen: 192, 3840 :ncol/nrow)
# sparsity: 0.047 | ffnn:  3904 | (seqlen: 192, 3904 :ncol/nrow)
# sparsity: 0.031 | ffnn:  3968 | (seqlen: 192, 3968 :ncol/nrow)
# sparsity: 0.016 | ffnn:  4032 | (seqlen: 192, 4032 :ncol/nrow)
# sparsity: 0.000 | ffnn:  4096 | (seqlen: 192, 4096 :ncol/nrow)
# sparsity: 0.996 | ffnn:    16 | (seqlen: 256,   16 :ncol/nrow)
# sparsity: 0.992 | ffnn:    32 | (seqlen: 256,   32 :ncol/nrow)
# sparsity: 0.988 | ffnn:    48 | (seqlen: 256,   48 :ncol/nrow)
# sparsity: 0.984 | ffnn:    64 | (seqlen: 256,   64 :ncol/nrow)
# sparsity: 0.980 | ffnn:    80 | (seqlen: 256,   80 :ncol/nrow)
# sparsity: 0.977 | ffnn:    96 | (seqlen: 256,   96 :ncol/nrow)
# sparsity: 0.973 | ffnn:   112 | (seqlen: 256,  112 :ncol/nrow)
# sparsity: 0.969 | ffnn:   128 | (seqlen: 256,  128 :ncol/nrow)
# sparsity: 0.965 | ffnn:   144 | (seqlen: 256,  144 :ncol/nrow)
# sparsity: 0.961 | ffnn:   160 | (seqlen: 256,  160 :ncol/nrow)
# sparsity: 0.957 | ffnn:   176 | (seqlen: 256,  176 :ncol/nrow)
# sparsity: 0.953 | ffnn:   192 | (seqlen: 256,  192 :ncol/nrow)
# sparsity: 0.949 | ffnn:   208 | (seqlen: 256,  208 :ncol/nrow)
# sparsity: 0.945 | ffnn:   224 | (seqlen: 256,  224 :ncol/nrow)
# sparsity: 0.941 | ffnn:   240 | (seqlen: 256,  240 :ncol/nrow)
# sparsity: 0.938 | ffnn:   256 | (seqlen: 256,  256 :ncol/nrow)
# sparsity: 0.934 | ffnn:   272 | (seqlen: 256,  272 :ncol/nrow)
# sparsity: 0.930 | ffnn:   288 | (seqlen: 256,  288 :ncol/nrow)
# sparsity: 0.926 | ffnn:   304 | (seqlen: 256,  304 :ncol/nrow)
# sparsity: 0.922 | ffnn:   320 | (seqlen: 256,  320 :ncol/nrow)
# sparsity: 0.918 | ffnn:   336 | (seqlen: 256,  336 :ncol/nrow)
# sparsity: 0.914 | ffnn:   352 | (seqlen: 256,  352 :ncol/nrow)
# sparsity: 0.910 | ffnn:   368 | (seqlen: 256,  368 :ncol/nrow)
# sparsity: 0.906 | ffnn:   384 | (seqlen: 256,  384 :ncol/nrow)
# sparsity: 0.902 | ffnn:   400 | (seqlen: 256,  400 :ncol/nrow)
# sparsity: 0.898 | ffnn:   416 | (seqlen: 256,  416 :ncol/nrow)
# sparsity: 0.895 | ffnn:   432 | (seqlen: 256,  432 :ncol/nrow)
# sparsity: 0.891 | ffnn:   448 | (seqlen: 256,  448 :ncol/nrow)
# sparsity: 0.887 | ffnn:   464 | (seqlen: 256,  464 :ncol/nrow)
# sparsity: 0.883 | ffnn:   480 | (seqlen: 256,  480 :ncol/nrow)
# sparsity: 0.879 | ffnn:   496 | (seqlen: 256,  496 :ncol/nrow)
# sparsity: 0.875 | ffnn:   512 | (seqlen: 256,  512 :ncol/nrow)
# sparsity: 0.871 | ffnn:   528 | (seqlen: 256,  528 :ncol/nrow)
# sparsity: 0.867 | ffnn:   544 | (seqlen: 256,  544 :ncol/nrow)
# sparsity: 0.863 | ffnn:   560 | (seqlen: 256,  560 :ncol/nrow)
# sparsity: 0.859 | ffnn:   576 | (seqlen: 256,  576 :ncol/nrow)
# sparsity: 0.855 | ffnn:   592 | (seqlen: 256,  592 :ncol/nrow)
# sparsity: 0.852 | ffnn:   608 | (seqlen: 256,  608 :ncol/nrow)
# sparsity: 0.848 | ffnn:   624 | (seqlen: 256,  624 :ncol/nrow)
# sparsity: 0.844 | ffnn:   640 | (seqlen: 256,  640 :ncol/nrow)
# sparsity: 0.840 | ffnn:   656 | (seqlen: 256,  656 :ncol/nrow)
# sparsity: 0.836 | ffnn:   672 | (seqlen: 256,  672 :ncol/nrow)
# sparsity: 0.832 | ffnn:   688 | (seqlen: 256,  688 :ncol/nrow)
# sparsity: 0.828 | ffnn:   704 | (seqlen: 256,  704 :ncol/nrow)
# sparsity: 0.824 | ffnn:   720 | (seqlen: 256,  720 :ncol/nrow)
# sparsity: 0.820 | ffnn:   736 | (seqlen: 256,  736 :ncol/nrow)
# sparsity: 0.816 | ffnn:   752 | (seqlen: 256,  752 :ncol/nrow)
# sparsity: 0.812 | ffnn:   768 | (seqlen: 256,  768 :ncol/nrow)
# sparsity: 0.809 | ffnn:   784 | (seqlen: 256,  784 :ncol/nrow)
# sparsity: 0.805 | ffnn:   800 | (seqlen: 256,  800 :ncol/nrow)
# sparsity: 0.801 | ffnn:   816 | (seqlen: 256,  816 :ncol/nrow)
# sparsity: 0.797 | ffnn:   832 | (seqlen: 256,  832 :ncol/nrow)
# sparsity: 0.793 | ffnn:   848 | (seqlen: 256,  848 :ncol/nrow)
# sparsity: 0.789 | ffnn:   864 | (seqlen: 256,  864 :ncol/nrow)
# sparsity: 0.785 | ffnn:   880 | (seqlen: 256,  880 :ncol/nrow)
# sparsity: 0.781 | ffnn:   896 | (seqlen: 256,  896 :ncol/nrow)
# sparsity: 0.777 | ffnn:   912 | (seqlen: 256,  912 :ncol/nrow)
# sparsity: 0.773 | ffnn:   928 | (seqlen: 256,  928 :ncol/nrow)
# sparsity: 0.770 | ffnn:   944 | (seqlen: 256,  944 :ncol/nrow)
# sparsity: 0.766 | ffnn:   960 | (seqlen: 256,  960 :ncol/nrow)
# sparsity: 0.762 | ffnn:   976 | (seqlen: 256,  976 :ncol/nrow)
# sparsity: 0.758 | ffnn:   992 | (seqlen: 256,  992 :ncol/nrow)
# sparsity: 0.754 | ffnn:  1008 | (seqlen: 256, 1008 :ncol/nrow)
# sparsity: 0.750 | ffnn:  1024 | (seqlen: 256, 1024 :ncol/nrow)
# sparsity: 0.746 | ffnn:  1040 | (seqlen: 256, 1040 :ncol/nrow)
# sparsity: 0.742 | ffnn:  1056 | (seqlen: 256, 1056 :ncol/nrow)
# sparsity: 0.738 | ffnn:  1072 | (seqlen: 256, 1072 :ncol/nrow)
# sparsity: 0.734 | ffnn:  1088 | (seqlen: 256, 1088 :ncol/nrow)
# sparsity: 0.730 | ffnn:  1104 | (seqlen: 256, 1104 :ncol/nrow)
# sparsity: 0.727 | ffnn:  1120 | (seqlen: 256, 1120 :ncol/nrow)
# sparsity: 0.723 | ffnn:  1136 | (seqlen: 256, 1136 :ncol/nrow)
# sparsity: 0.719 | ffnn:  1152 | (seqlen: 256, 1152 :ncol/nrow)
# sparsity: 0.715 | ffnn:  1168 | (seqlen: 256, 1168 :ncol/nrow)
# sparsity: 0.711 | ffnn:  1184 | (seqlen: 256, 1184 :ncol/nrow)
# sparsity: 0.707 | ffnn:  1200 | (seqlen: 256, 1200 :ncol/nrow)
# sparsity: 0.703 | ffnn:  1216 | (seqlen: 256, 1216 :ncol/nrow)
# sparsity: 0.699 | ffnn:  1232 | (seqlen: 256, 1232 :ncol/nrow)
# sparsity: 0.695 | ffnn:  1248 | (seqlen: 256, 1248 :ncol/nrow)
# sparsity: 0.691 | ffnn:  1264 | (seqlen: 256, 1264 :ncol/nrow)
# sparsity: 0.688 | ffnn:  1280 | (seqlen: 256, 1280 :ncol/nrow)
# sparsity: 0.684 | ffnn:  1296 | (seqlen: 256, 1296 :ncol/nrow)
# sparsity: 0.680 | ffnn:  1312 | (seqlen: 256, 1312 :ncol/nrow)
# sparsity: 0.676 | ffnn:  1328 | (seqlen: 256, 1328 :ncol/nrow)
# sparsity: 0.672 | ffnn:  1344 | (seqlen: 256, 1344 :ncol/nrow)
# sparsity: 0.668 | ffnn:  1360 | (seqlen: 256, 1360 :ncol/nrow)
# sparsity: 0.664 | ffnn:  1376 | (seqlen: 256, 1376 :ncol/nrow)
# sparsity: 0.660 | ffnn:  1392 | (seqlen: 256, 1392 :ncol/nrow)
# sparsity: 0.656 | ffnn:  1408 | (seqlen: 256, 1408 :ncol/nrow)
# sparsity: 0.652 | ffnn:  1424 | (seqlen: 256, 1424 :ncol/nrow)
# sparsity: 0.648 | ffnn:  1440 | (seqlen: 256, 1440 :ncol/nrow)
# sparsity: 0.645 | ffnn:  1456 | (seqlen: 256, 1456 :ncol/nrow)
# sparsity: 0.641 | ffnn:  1472 | (seqlen: 256, 1472 :ncol/nrow)
# sparsity: 0.637 | ffnn:  1488 | (seqlen: 256, 1488 :ncol/nrow)
# sparsity: 0.633 | ffnn:  1504 | (seqlen: 256, 1504 :ncol/nrow)
# sparsity: 0.629 | ffnn:  1520 | (seqlen: 256, 1520 :ncol/nrow)
# sparsity: 0.625 | ffnn:  1536 | (seqlen: 256, 1536 :ncol/nrow)
# sparsity: 0.621 | ffnn:  1552 | (seqlen: 256, 1552 :ncol/nrow)
# sparsity: 0.617 | ffnn:  1568 | (seqlen: 256, 1568 :ncol/nrow)
# sparsity: 0.613 | ffnn:  1584 | (seqlen: 256, 1584 :ncol/nrow)
# sparsity: 0.609 | ffnn:  1600 | (seqlen: 256, 1600 :ncol/nrow)
# sparsity: 0.605 | ffnn:  1616 | (seqlen: 256, 1616 :ncol/nrow)
# sparsity: 0.602 | ffnn:  1632 | (seqlen: 256, 1632 :ncol/nrow)
# sparsity: 0.598 | ffnn:  1648 | (seqlen: 256, 1648 :ncol/nrow)
# sparsity: 0.594 | ffnn:  1664 | (seqlen: 256, 1664 :ncol/nrow)
# sparsity: 0.590 | ffnn:  1680 | (seqlen: 256, 1680 :ncol/nrow)
# sparsity: 0.586 | ffnn:  1696 | (seqlen: 256, 1696 :ncol/nrow)
# sparsity: 0.582 | ffnn:  1712 | (seqlen: 256, 1712 :ncol/nrow)
# sparsity: 0.578 | ffnn:  1728 | (seqlen: 256, 1728 :ncol/nrow)
# sparsity: 0.574 | ffnn:  1744 | (seqlen: 256, 1744 :ncol/nrow)
# sparsity: 0.570 | ffnn:  1760 | (seqlen: 256, 1760 :ncol/nrow)
# sparsity: 0.566 | ffnn:  1776 | (seqlen: 256, 1776 :ncol/nrow)
# sparsity: 0.562 | ffnn:  1792 | (seqlen: 256, 1792 :ncol/nrow)
# sparsity: 0.559 | ffnn:  1808 | (seqlen: 256, 1808 :ncol/nrow)
# sparsity: 0.555 | ffnn:  1824 | (seqlen: 256, 1824 :ncol/nrow)
# sparsity: 0.551 | ffnn:  1840 | (seqlen: 256, 1840 :ncol/nrow)
# sparsity: 0.547 | ffnn:  1856 | (seqlen: 256, 1856 :ncol/nrow)
# sparsity: 0.543 | ffnn:  1872 | (seqlen: 256, 1872 :ncol/nrow)
# sparsity: 0.539 | ffnn:  1888 | (seqlen: 256, 1888 :ncol/nrow)
# sparsity: 0.535 | ffnn:  1904 | (seqlen: 256, 1904 :ncol/nrow)
# sparsity: 0.531 | ffnn:  1920 | (seqlen: 256, 1920 :ncol/nrow)
# sparsity: 0.527 | ffnn:  1936 | (seqlen: 256, 1936 :ncol/nrow)
# sparsity: 0.523 | ffnn:  1952 | (seqlen: 256, 1952 :ncol/nrow)
# sparsity: 0.520 | ffnn:  1968 | (seqlen: 256, 1968 :ncol/nrow)
# sparsity: 0.516 | ffnn:  1984 | (seqlen: 256, 1984 :ncol/nrow)
# sparsity: 0.512 | ffnn:  2000 | (seqlen: 256, 2000 :ncol/nrow)
# sparsity: 0.508 | ffnn:  2016 | (seqlen: 256, 2016 :ncol/nrow)
# sparsity: 0.504 | ffnn:  2032 | (seqlen: 256, 2032 :ncol/nrow)
# sparsity: 0.500 | ffnn:  2048 | (seqlen: 256, 2048 :ncol/nrow)
# sparsity: 0.496 | ffnn:  2064 | (seqlen: 256, 2064 :ncol/nrow)
# sparsity: 0.492 | ffnn:  2080 | (seqlen: 256, 2080 :ncol/nrow)
# sparsity: 0.488 | ffnn:  2096 | (seqlen: 256, 2096 :ncol/nrow)
# sparsity: 0.484 | ffnn:  2112 | (seqlen: 256, 2112 :ncol/nrow)
# sparsity: 0.480 | ffnn:  2128 | (seqlen: 256, 2128 :ncol/nrow)
# sparsity: 0.477 | ffnn:  2144 | (seqlen: 256, 2144 :ncol/nrow)
# sparsity: 0.473 | ffnn:  2160 | (seqlen: 256, 2160 :ncol/nrow)
# sparsity: 0.469 | ffnn:  2176 | (seqlen: 256, 2176 :ncol/nrow)
# sparsity: 0.465 | ffnn:  2192 | (seqlen: 256, 2192 :ncol/nrow)
# sparsity: 0.461 | ffnn:  2208 | (seqlen: 256, 2208 :ncol/nrow)
# sparsity: 0.457 | ffnn:  2224 | (seqlen: 256, 2224 :ncol/nrow)
# sparsity: 0.453 | ffnn:  2240 | (seqlen: 256, 2240 :ncol/nrow)
# sparsity: 0.449 | ffnn:  2256 | (seqlen: 256, 2256 :ncol/nrow)
# sparsity: 0.445 | ffnn:  2272 | (seqlen: 256, 2272 :ncol/nrow)
# sparsity: 0.441 | ffnn:  2288 | (seqlen: 256, 2288 :ncol/nrow)
# sparsity: 0.438 | ffnn:  2304 | (seqlen: 256, 2304 :ncol/nrow)
# sparsity: 0.434 | ffnn:  2320 | (seqlen: 256, 2320 :ncol/nrow)
# sparsity: 0.430 | ffnn:  2336 | (seqlen: 256, 2336 :ncol/nrow)
# sparsity: 0.426 | ffnn:  2352 | (seqlen: 256, 2352 :ncol/nrow)
# sparsity: 0.422 | ffnn:  2368 | (seqlen: 256, 2368 :ncol/nrow)
# sparsity: 0.418 | ffnn:  2384 | (seqlen: 256, 2384 :ncol/nrow)
# sparsity: 0.414 | ffnn:  2400 | (seqlen: 256, 2400 :ncol/nrow)
# sparsity: 0.410 | ffnn:  2416 | (seqlen: 256, 2416 :ncol/nrow)
# sparsity: 0.406 | ffnn:  2432 | (seqlen: 256, 2432 :ncol/nrow)
# sparsity: 0.402 | ffnn:  2448 | (seqlen: 256, 2448 :ncol/nrow)
# sparsity: 0.398 | ffnn:  2464 | (seqlen: 256, 2464 :ncol/nrow)
# sparsity: 0.395 | ffnn:  2480 | (seqlen: 256, 2480 :ncol/nrow)
# sparsity: 0.391 | ffnn:  2496 | (seqlen: 256, 2496 :ncol/nrow)
# sparsity: 0.387 | ffnn:  2512 | (seqlen: 256, 2512 :ncol/nrow)
# sparsity: 0.383 | ffnn:  2528 | (seqlen: 256, 2528 :ncol/nrow)
# sparsity: 0.379 | ffnn:  2544 | (seqlen: 256, 2544 :ncol/nrow)
# sparsity: 0.375 | ffnn:  2560 | (seqlen: 256, 2560 :ncol/nrow)
# sparsity: 0.371 | ffnn:  2576 | (seqlen: 256, 2576 :ncol/nrow)
# sparsity: 0.367 | ffnn:  2592 | (seqlen: 256, 2592 :ncol/nrow)
# sparsity: 0.363 | ffnn:  2608 | (seqlen: 256, 2608 :ncol/nrow)
# sparsity: 0.359 | ffnn:  2624 | (seqlen: 256, 2624 :ncol/nrow)
# sparsity: 0.355 | ffnn:  2640 | (seqlen: 256, 2640 :ncol/nrow)
# sparsity: 0.352 | ffnn:  2656 | (seqlen: 256, 2656 :ncol/nrow)
# sparsity: 0.348 | ffnn:  2672 | (seqlen: 256, 2672 :ncol/nrow)
# sparsity: 0.344 | ffnn:  2688 | (seqlen: 256, 2688 :ncol/nrow)
# sparsity: 0.340 | ffnn:  2704 | (seqlen: 256, 2704 :ncol/nrow)
# sparsity: 0.336 | ffnn:  2720 | (seqlen: 256, 2720 :ncol/nrow)
# sparsity: 0.332 | ffnn:  2736 | (seqlen: 256, 2736 :ncol/nrow)
# sparsity: 0.328 | ffnn:  2752 | (seqlen: 256, 2752 :ncol/nrow)
# sparsity: 0.324 | ffnn:  2768 | (seqlen: 256, 2768 :ncol/nrow)
# sparsity: 0.320 | ffnn:  2784 | (seqlen: 256, 2784 :ncol/nrow)
# sparsity: 0.316 | ffnn:  2800 | (seqlen: 256, 2800 :ncol/nrow)
# sparsity: 0.312 | ffnn:  2816 | (seqlen: 256, 2816 :ncol/nrow)
# sparsity: 0.309 | ffnn:  2832 | (seqlen: 256, 2832 :ncol/nrow)
# sparsity: 0.305 | ffnn:  2848 | (seqlen: 256, 2848 :ncol/nrow)
# sparsity: 0.301 | ffnn:  2864 | (seqlen: 256, 2864 :ncol/nrow)
# sparsity: 0.297 | ffnn:  2880 | (seqlen: 256, 2880 :ncol/nrow)
# sparsity: 0.293 | ffnn:  2896 | (seqlen: 256, 2896 :ncol/nrow)
# sparsity: 0.289 | ffnn:  2912 | (seqlen: 256, 2912 :ncol/nrow)
# sparsity: 0.285 | ffnn:  2928 | (seqlen: 256, 2928 :ncol/nrow)
# sparsity: 0.281 | ffnn:  2944 | (seqlen: 256, 2944 :ncol/nrow)
# sparsity: 0.277 | ffnn:  2960 | (seqlen: 256, 2960 :ncol/nrow)
# sparsity: 0.273 | ffnn:  2976 | (seqlen: 256, 2976 :ncol/nrow)
# sparsity: 0.270 | ffnn:  2992 | (seqlen: 256, 2992 :ncol/nrow)
# sparsity: 0.266 | ffnn:  3008 | (seqlen: 256, 3008 :ncol/nrow)
# sparsity: 0.262 | ffnn:  3024 | (seqlen: 256, 3024 :ncol/nrow)
# sparsity: 0.258 | ffnn:  3040 | (seqlen: 256, 3040 :ncol/nrow)
# sparsity: 0.254 | ffnn:  3056 | (seqlen: 256, 3056 :ncol/nrow)
# sparsity: 0.250 | ffnn:  3072 | (seqlen: 256, 3072 :ncol/nrow)
# sparsity: 0.246 | ffnn:  3088 | (seqlen: 256, 3088 :ncol/nrow)
# sparsity: 0.242 | ffnn:  3104 | (seqlen: 256, 3104 :ncol/nrow)
# sparsity: 0.238 | ffnn:  3120 | (seqlen: 256, 3120 :ncol/nrow)
# sparsity: 0.234 | ffnn:  3136 | (seqlen: 256, 3136 :ncol/nrow)
# sparsity: 0.230 | ffnn:  3152 | (seqlen: 256, 3152 :ncol/nrow)
# sparsity: 0.227 | ffnn:  3168 | (seqlen: 256, 3168 :ncol/nrow)
# sparsity: 0.223 | ffnn:  3184 | (seqlen: 256, 3184 :ncol/nrow)
# sparsity: 0.219 | ffnn:  3200 | (seqlen: 256, 3200 :ncol/nrow)
# sparsity: 0.215 | ffnn:  3216 | (seqlen: 256, 3216 :ncol/nrow)
# sparsity: 0.211 | ffnn:  3232 | (seqlen: 256, 3232 :ncol/nrow)
# sparsity: 0.207 | ffnn:  3248 | (seqlen: 256, 3248 :ncol/nrow)
# sparsity: 0.203 | ffnn:  3264 | (seqlen: 256, 3264 :ncol/nrow)
# sparsity: 0.199 | ffnn:  3280 | (seqlen: 256, 3280 :ncol/nrow)
# sparsity: 0.195 | ffnn:  3296 | (seqlen: 256, 3296 :ncol/nrow)
# sparsity: 0.191 | ffnn:  3312 | (seqlen: 256, 3312 :ncol/nrow)
# sparsity: 0.188 | ffnn:  3328 | (seqlen: 256, 3328 :ncol/nrow)
# sparsity: 0.184 | ffnn:  3344 | (seqlen: 256, 3344 :ncol/nrow)
# sparsity: 0.180 | ffnn:  3360 | (seqlen: 256, 3360 :ncol/nrow)
# sparsity: 0.176 | ffnn:  3376 | (seqlen: 256, 3376 :ncol/nrow)
# sparsity: 0.172 | ffnn:  3392 | (seqlen: 256, 3392 :ncol/nrow)
# sparsity: 0.168 | ffnn:  3408 | (seqlen: 256, 3408 :ncol/nrow)
# sparsity: 0.164 | ffnn:  3424 | (seqlen: 256, 3424 :ncol/nrow)
# sparsity: 0.160 | ffnn:  3440 | (seqlen: 256, 3440 :ncol/nrow)
# sparsity: 0.156 | ffnn:  3456 | (seqlen: 256, 3456 :ncol/nrow)
# sparsity: 0.152 | ffnn:  3472 | (seqlen: 256, 3472 :ncol/nrow)
# sparsity: 0.148 | ffnn:  3488 | (seqlen: 256, 3488 :ncol/nrow)
# sparsity: 0.145 | ffnn:  3504 | (seqlen: 256, 3504 :ncol/nrow)
# sparsity: 0.141 | ffnn:  3520 | (seqlen: 256, 3520 :ncol/nrow)
# sparsity: 0.137 | ffnn:  3536 | (seqlen: 256, 3536 :ncol/nrow)
# sparsity: 0.133 | ffnn:  3552 | (seqlen: 256, 3552 :ncol/nrow)
# sparsity: 0.129 | ffnn:  3568 | (seqlen: 256, 3568 :ncol/nrow)
# sparsity: 0.125 | ffnn:  3584 | (seqlen: 256, 3584 :ncol/nrow)
# sparsity: 0.121 | ffnn:  3600 | (seqlen: 256, 3600 :ncol/nrow)
# sparsity: 0.117 | ffnn:  3616 | (seqlen: 256, 3616 :ncol/nrow)
# sparsity: 0.113 | ffnn:  3632 | (seqlen: 256, 3632 :ncol/nrow)
# sparsity: 0.109 | ffnn:  3648 | (seqlen: 256, 3648 :ncol/nrow)
# sparsity: 0.105 | ffnn:  3664 | (seqlen: 256, 3664 :ncol/nrow)
# sparsity: 0.102 | ffnn:  3680 | (seqlen: 256, 3680 :ncol/nrow)
# sparsity: 0.098 | ffnn:  3696 | (seqlen: 256, 3696 :ncol/nrow)
# sparsity: 0.094 | ffnn:  3712 | (seqlen: 256, 3712 :ncol/nrow)
# sparsity: 0.090 | ffnn:  3728 | (seqlen: 256, 3728 :ncol/nrow)
# sparsity: 0.086 | ffnn:  3744 | (seqlen: 256, 3744 :ncol/nrow)
# sparsity: 0.082 | ffnn:  3760 | (seqlen: 256, 3760 :ncol/nrow)
# sparsity: 0.078 | ffnn:  3776 | (seqlen: 256, 3776 :ncol/nrow)
# sparsity: 0.074 | ffnn:  3792 | (seqlen: 256, 3792 :ncol/nrow)
# sparsity: 0.070 | ffnn:  3808 | (seqlen: 256, 3808 :ncol/nrow)
# sparsity: 0.066 | ffnn:  3824 | (seqlen: 256, 3824 :ncol/nrow)
# sparsity: 0.062 | ffnn:  3840 | (seqlen: 256, 3840 :ncol/nrow)
# sparsity: 0.059 | ffnn:  3856 | (seqlen: 256, 3856 :ncol/nrow)
# sparsity: 0.055 | ffnn:  3872 | (seqlen: 256, 3872 :ncol/nrow)
# sparsity: 0.051 | ffnn:  3888 | (seqlen: 256, 3888 :ncol/nrow)
# sparsity: 0.047 | ffnn:  3904 | (seqlen: 256, 3904 :ncol/nrow)
# sparsity: 0.043 | ffnn:  3920 | (seqlen: 256, 3920 :ncol/nrow)
# sparsity: 0.039 | ffnn:  3936 | (seqlen: 256, 3936 :ncol/nrow)
# sparsity: 0.035 | ffnn:  3952 | (seqlen: 256, 3952 :ncol/nrow)
# sparsity: 0.031 | ffnn:  3968 | (seqlen: 256, 3968 :ncol/nrow)
# sparsity: 0.027 | ffnn:  3984 | (seqlen: 256, 3984 :ncol/nrow)
# sparsity: 0.023 | ffnn:  4000 | (seqlen: 256, 4000 :ncol/nrow)
# sparsity: 0.020 | ffnn:  4016 | (seqlen: 256, 4016 :ncol/nrow)
# sparsity: 0.016 | ffnn:  4032 | (seqlen: 256, 4032 :ncol/nrow)
# sparsity: 0.012 | ffnn:  4048 | (seqlen: 256, 4048 :ncol/nrow)
# sparsity: 0.008 | ffnn:  4064 | (seqlen: 256, 4064 :ncol/nrow)
# sparsity: 0.004 | ffnn:  4080 | (seqlen: 256, 4080 :ncol/nrow)
# sparsity: 0.000 | ffnn:  4096 | (seqlen: 256, 4096 :ncol/nrow)
# sparsity: 0.984 | ffnn:    64 | (seqlen: 320,   64 :ncol/nrow)
# sparsity: 0.969 | ffnn:   128 | (seqlen: 320,  128 :ncol/nrow)
# sparsity: 0.953 | ffnn:   192 | (seqlen: 320,  192 :ncol/nrow)
# sparsity: 0.938 | ffnn:   256 | (seqlen: 320,  256 :ncol/nrow)
# sparsity: 0.922 | ffnn:   320 | (seqlen: 320,  320 :ncol/nrow)
# sparsity: 0.906 | ffnn:   384 | (seqlen: 320,  384 :ncol/nrow)
# sparsity: 0.891 | ffnn:   448 | (seqlen: 320,  448 :ncol/nrow)
# sparsity: 0.875 | ffnn:   512 | (seqlen: 320,  512 :ncol/nrow)
# sparsity: 0.859 | ffnn:   576 | (seqlen: 320,  576 :ncol/nrow)
# sparsity: 0.844 | ffnn:   640 | (seqlen: 320,  640 :ncol/nrow)
# sparsity: 0.828 | ffnn:   704 | (seqlen: 320,  704 :ncol/nrow)
# sparsity: 0.812 | ffnn:   768 | (seqlen: 320,  768 :ncol/nrow)
# sparsity: 0.797 | ffnn:   832 | (seqlen: 320,  832 :ncol/nrow)
# sparsity: 0.781 | ffnn:   896 | (seqlen: 320,  896 :ncol/nrow)
# sparsity: 0.766 | ffnn:   960 | (seqlen: 320,  960 :ncol/nrow)
# sparsity: 0.750 | ffnn:  1024 | (seqlen: 320, 1024 :ncol/nrow)
# sparsity: 0.734 | ffnn:  1088 | (seqlen: 320, 1088 :ncol/nrow)
# sparsity: 0.719 | ffnn:  1152 | (seqlen: 320, 1152 :ncol/nrow)
# sparsity: 0.703 | ffnn:  1216 | (seqlen: 320, 1216 :ncol/nrow)
# sparsity: 0.688 | ffnn:  1280 | (seqlen: 320, 1280 :ncol/nrow)
# sparsity: 0.672 | ffnn:  1344 | (seqlen: 320, 1344 :ncol/nrow)
# sparsity: 0.656 | ffnn:  1408 | (seqlen: 320, 1408 :ncol/nrow)
# sparsity: 0.641 | ffnn:  1472 | (seqlen: 320, 1472 :ncol/nrow)
# sparsity: 0.625 | ffnn:  1536 | (seqlen: 320, 1536 :ncol/nrow)
# sparsity: 0.609 | ffnn:  1600 | (seqlen: 320, 1600 :ncol/nrow)
# sparsity: 0.594 | ffnn:  1664 | (seqlen: 320, 1664 :ncol/nrow)
# sparsity: 0.578 | ffnn:  1728 | (seqlen: 320, 1728 :ncol/nrow)
# sparsity: 0.562 | ffnn:  1792 | (seqlen: 320, 1792 :ncol/nrow)
# sparsity: 0.547 | ffnn:  1856 | (seqlen: 320, 1856 :ncol/nrow)
# sparsity: 0.531 | ffnn:  1920 | (seqlen: 320, 1920 :ncol/nrow)
# sparsity: 0.516 | ffnn:  1984 | (seqlen: 320, 1984 :ncol/nrow)
# sparsity: 0.500 | ffnn:  2048 | (seqlen: 320, 2048 :ncol/nrow)
# sparsity: 0.484 | ffnn:  2112 | (seqlen: 320, 2112 :ncol/nrow)
# sparsity: 0.469 | ffnn:  2176 | (seqlen: 320, 2176 :ncol/nrow)
# sparsity: 0.453 | ffnn:  2240 | (seqlen: 320, 2240 :ncol/nrow)
# sparsity: 0.438 | ffnn:  2304 | (seqlen: 320, 2304 :ncol/nrow)
# sparsity: 0.422 | ffnn:  2368 | (seqlen: 320, 2368 :ncol/nrow)
# sparsity: 0.406 | ffnn:  2432 | (seqlen: 320, 2432 :ncol/nrow)
# sparsity: 0.391 | ffnn:  2496 | (seqlen: 320, 2496 :ncol/nrow)
# sparsity: 0.375 | ffnn:  2560 | (seqlen: 320, 2560 :ncol/nrow)
# sparsity: 0.359 | ffnn:  2624 | (seqlen: 320, 2624 :ncol/nrow)
# sparsity: 0.344 | ffnn:  2688 | (seqlen: 320, 2688 :ncol/nrow)
# sparsity: 0.328 | ffnn:  2752 | (seqlen: 320, 2752 :ncol/nrow)
# sparsity: 0.312 | ffnn:  2816 | (seqlen: 320, 2816 :ncol/nrow)
# sparsity: 0.297 | ffnn:  2880 | (seqlen: 320, 2880 :ncol/nrow)
# sparsity: 0.281 | ffnn:  2944 | (seqlen: 320, 2944 :ncol/nrow)
# sparsity: 0.266 | ffnn:  3008 | (seqlen: 320, 3008 :ncol/nrow)
# sparsity: 0.250 | ffnn:  3072 | (seqlen: 320, 3072 :ncol/nrow)
# sparsity: 0.234 | ffnn:  3136 | (seqlen: 320, 3136 :ncol/nrow)
# sparsity: 0.219 | ffnn:  3200 | (seqlen: 320, 3200 :ncol/nrow)
# sparsity: 0.203 | ffnn:  3264 | (seqlen: 320, 3264 :ncol/nrow)
# sparsity: 0.188 | ffnn:  3328 | (seqlen: 320, 3328 :ncol/nrow)
# sparsity: 0.172 | ffnn:  3392 | (seqlen: 320, 3392 :ncol/nrow)
# sparsity: 0.156 | ffnn:  3456 | (seqlen: 320, 3456 :ncol/nrow)
# sparsity: 0.141 | ffnn:  3520 | (seqlen: 320, 3520 :ncol/nrow)
# sparsity: 0.125 | ffnn:  3584 | (seqlen: 320, 3584 :ncol/nrow)
# sparsity: 0.109 | ffnn:  3648 | (seqlen: 320, 3648 :ncol/nrow)
# sparsity: 0.094 | ffnn:  3712 | (seqlen: 320, 3712 :ncol/nrow)
# sparsity: 0.078 | ffnn:  3776 | (seqlen: 320, 3776 :ncol/nrow)
# sparsity: 0.062 | ffnn:  3840 | (seqlen: 320, 3840 :ncol/nrow)
# sparsity: 0.047 | ffnn:  3904 | (seqlen: 320, 3904 :ncol/nrow)
# sparsity: 0.031 | ffnn:  3968 | (seqlen: 320, 3968 :ncol/nrow)
# sparsity: 0.016 | ffnn:  4032 | (seqlen: 320, 4032 :ncol/nrow)
# sparsity: 0.000 | ffnn:  4096 | (seqlen: 320, 4096 :ncol/nrow)
# sparsity: 0.992 | ffnn:    32 | (seqlen: 384,   32 :ncol/nrow)
# sparsity: 0.984 | ffnn:    64 | (seqlen: 384,   64 :ncol/nrow)
# sparsity: 0.977 | ffnn:    96 | (seqlen: 384,   96 :ncol/nrow)
# sparsity: 0.969 | ffnn:   128 | (seqlen: 384,  128 :ncol/nrow)
# sparsity: 0.961 | ffnn:   160 | (seqlen: 384,  160 :ncol/nrow)
# sparsity: 0.953 | ffnn:   192 | (seqlen: 384,  192 :ncol/nrow)
# sparsity: 0.945 | ffnn:   224 | (seqlen: 384,  224 :ncol/nrow)
# sparsity: 0.938 | ffnn:   256 | (seqlen: 384,  256 :ncol/nrow)
# sparsity: 0.930 | ffnn:   288 | (seqlen: 384,  288 :ncol/nrow)
# sparsity: 0.922 | ffnn:   320 | (seqlen: 384,  320 :ncol/nrow)
# sparsity: 0.914 | ffnn:   352 | (seqlen: 384,  352 :ncol/nrow)
# sparsity: 0.906 | ffnn:   384 | (seqlen: 384,  384 :ncol/nrow)
# sparsity: 0.898 | ffnn:   416 | (seqlen: 384,  416 :ncol/nrow)
# sparsity: 0.891 | ffnn:   448 | (seqlen: 384,  448 :ncol/nrow)
# sparsity: 0.883 | ffnn:   480 | (seqlen: 384,  480 :ncol/nrow)
# sparsity: 0.875 | ffnn:   512 | (seqlen: 384,  512 :ncol/nrow)
# sparsity: 0.867 | ffnn:   544 | (seqlen: 384,  544 :ncol/nrow)
# sparsity: 0.859 | ffnn:   576 | (seqlen: 384,  576 :ncol/nrow)
# sparsity: 0.852 | ffnn:   608 | (seqlen: 384,  608 :ncol/nrow)
# sparsity: 0.844 | ffnn:   640 | (seqlen: 384,  640 :ncol/nrow)
# sparsity: 0.836 | ffnn:   672 | (seqlen: 384,  672 :ncol/nrow)
# sparsity: 0.828 | ffnn:   704 | (seqlen: 384,  704 :ncol/nrow)
# sparsity: 0.820 | ffnn:   736 | (seqlen: 384,  736 :ncol/nrow)
# sparsity: 0.812 | ffnn:   768 | (seqlen: 384,  768 :ncol/nrow)
# sparsity: 0.805 | ffnn:   800 | (seqlen: 384,  800 :ncol/nrow)
# sparsity: 0.797 | ffnn:   832 | (seqlen: 384,  832 :ncol/nrow)
# sparsity: 0.789 | ffnn:   864 | (seqlen: 384,  864 :ncol/nrow)
# sparsity: 0.781 | ffnn:   896 | (seqlen: 384,  896 :ncol/nrow)
# sparsity: 0.773 | ffnn:   928 | (seqlen: 384,  928 :ncol/nrow)
# sparsity: 0.766 | ffnn:   960 | (seqlen: 384,  960 :ncol/nrow)
# sparsity: 0.758 | ffnn:   992 | (seqlen: 384,  992 :ncol/nrow)
# sparsity: 0.750 | ffnn:  1024 | (seqlen: 384, 1024 :ncol/nrow)
# sparsity: 0.742 | ffnn:  1056 | (seqlen: 384, 1056 :ncol/nrow)
# sparsity: 0.734 | ffnn:  1088 | (seqlen: 384, 1088 :ncol/nrow)
# sparsity: 0.727 | ffnn:  1120 | (seqlen: 384, 1120 :ncol/nrow)
# sparsity: 0.719 | ffnn:  1152 | (seqlen: 384, 1152 :ncol/nrow)
# sparsity: 0.711 | ffnn:  1184 | (seqlen: 384, 1184 :ncol/nrow)
# sparsity: 0.703 | ffnn:  1216 | (seqlen: 384, 1216 :ncol/nrow)
# sparsity: 0.695 | ffnn:  1248 | (seqlen: 384, 1248 :ncol/nrow)
# sparsity: 0.688 | ffnn:  1280 | (seqlen: 384, 1280 :ncol/nrow)
# sparsity: 0.680 | ffnn:  1312 | (seqlen: 384, 1312 :ncol/nrow)
# sparsity: 0.672 | ffnn:  1344 | (seqlen: 384, 1344 :ncol/nrow)
# sparsity: 0.664 | ffnn:  1376 | (seqlen: 384, 1376 :ncol/nrow)
# sparsity: 0.656 | ffnn:  1408 | (seqlen: 384, 1408 :ncol/nrow)
# sparsity: 0.648 | ffnn:  1440 | (seqlen: 384, 1440 :ncol/nrow)
# sparsity: 0.641 | ffnn:  1472 | (seqlen: 384, 1472 :ncol/nrow)
# sparsity: 0.633 | ffnn:  1504 | (seqlen: 384, 1504 :ncol/nrow)
# sparsity: 0.625 | ffnn:  1536 | (seqlen: 384, 1536 :ncol/nrow)
# sparsity: 0.617 | ffnn:  1568 | (seqlen: 384, 1568 :ncol/nrow)
# sparsity: 0.609 | ffnn:  1600 | (seqlen: 384, 1600 :ncol/nrow)
# sparsity: 0.602 | ffnn:  1632 | (seqlen: 384, 1632 :ncol/nrow)
# sparsity: 0.594 | ffnn:  1664 | (seqlen: 384, 1664 :ncol/nrow)
# sparsity: 0.586 | ffnn:  1696 | (seqlen: 384, 1696 :ncol/nrow)
# sparsity: 0.578 | ffnn:  1728 | (seqlen: 384, 1728 :ncol/nrow)
# sparsity: 0.570 | ffnn:  1760 | (seqlen: 384, 1760 :ncol/nrow)
# sparsity: 0.562 | ffnn:  1792 | (seqlen: 384, 1792 :ncol/nrow)
# sparsity: 0.555 | ffnn:  1824 | (seqlen: 384, 1824 :ncol/nrow)
# sparsity: 0.547 | ffnn:  1856 | (seqlen: 384, 1856 :ncol/nrow)
# sparsity: 0.539 | ffnn:  1888 | (seqlen: 384, 1888 :ncol/nrow)
# sparsity: 0.531 | ffnn:  1920 | (seqlen: 384, 1920 :ncol/nrow)
# sparsity: 0.523 | ffnn:  1952 | (seqlen: 384, 1952 :ncol/nrow)
# sparsity: 0.516 | ffnn:  1984 | (seqlen: 384, 1984 :ncol/nrow)
# sparsity: 0.508 | ffnn:  2016 | (seqlen: 384, 2016 :ncol/nrow)
# sparsity: 0.500 | ffnn:  2048 | (seqlen: 384, 2048 :ncol/nrow)
# sparsity: 0.492 | ffnn:  2080 | (seqlen: 384, 2080 :ncol/nrow)
# sparsity: 0.484 | ffnn:  2112 | (seqlen: 384, 2112 :ncol/nrow)
# sparsity: 0.477 | ffnn:  2144 | (seqlen: 384, 2144 :ncol/nrow)
# sparsity: 0.469 | ffnn:  2176 | (seqlen: 384, 2176 :ncol/nrow)
# sparsity: 0.461 | ffnn:  2208 | (seqlen: 384, 2208 :ncol/nrow)
# sparsity: 0.453 | ffnn:  2240 | (seqlen: 384, 2240 :ncol/nrow)
# sparsity: 0.445 | ffnn:  2272 | (seqlen: 384, 2272 :ncol/nrow)
# sparsity: 0.438 | ffnn:  2304 | (seqlen: 384, 2304 :ncol/nrow)
# sparsity: 0.430 | ffnn:  2336 | (seqlen: 384, 2336 :ncol/nrow)
# sparsity: 0.422 | ffnn:  2368 | (seqlen: 384, 2368 :ncol/nrow)
# sparsity: 0.414 | ffnn:  2400 | (seqlen: 384, 2400 :ncol/nrow)
# sparsity: 0.406 | ffnn:  2432 | (seqlen: 384, 2432 :ncol/nrow)
# sparsity: 0.398 | ffnn:  2464 | (seqlen: 384, 2464 :ncol/nrow)
# sparsity: 0.391 | ffnn:  2496 | (seqlen: 384, 2496 :ncol/nrow)
# sparsity: 0.383 | ffnn:  2528 | (seqlen: 384, 2528 :ncol/nrow)
# sparsity: 0.375 | ffnn:  2560 | (seqlen: 384, 2560 :ncol/nrow)
# sparsity: 0.367 | ffnn:  2592 | (seqlen: 384, 2592 :ncol/nrow)
# sparsity: 0.359 | ffnn:  2624 | (seqlen: 384, 2624 :ncol/nrow)
# sparsity: 0.352 | ffnn:  2656 | (seqlen: 384, 2656 :ncol/nrow)
# sparsity: 0.344 | ffnn:  2688 | (seqlen: 384, 2688 :ncol/nrow)
# sparsity: 0.336 | ffnn:  2720 | (seqlen: 384, 2720 :ncol/nrow)
# sparsity: 0.328 | ffnn:  2752 | (seqlen: 384, 2752 :ncol/nrow)
# sparsity: 0.320 | ffnn:  2784 | (seqlen: 384, 2784 :ncol/nrow)
# sparsity: 0.312 | ffnn:  2816 | (seqlen: 384, 2816 :ncol/nrow)
# sparsity: 0.305 | ffnn:  2848 | (seqlen: 384, 2848 :ncol/nrow)
# sparsity: 0.297 | ffnn:  2880 | (seqlen: 384, 2880 :ncol/nrow)
# sparsity: 0.289 | ffnn:  2912 | (seqlen: 384, 2912 :ncol/nrow)
# sparsity: 0.281 | ffnn:  2944 | (seqlen: 384, 2944 :ncol/nrow)
# sparsity: 0.273 | ffnn:  2976 | (seqlen: 384, 2976 :ncol/nrow)
# sparsity: 0.266 | ffnn:  3008 | (seqlen: 384, 3008 :ncol/nrow)
# sparsity: 0.258 | ffnn:  3040 | (seqlen: 384, 3040 :ncol/nrow)
# sparsity: 0.250 | ffnn:  3072 | (seqlen: 384, 3072 :ncol/nrow)
# sparsity: 0.242 | ffnn:  3104 | (seqlen: 384, 3104 :ncol/nrow)
# sparsity: 0.234 | ffnn:  3136 | (seqlen: 384, 3136 :ncol/nrow)
# sparsity: 0.227 | ffnn:  3168 | (seqlen: 384, 3168 :ncol/nrow)
# sparsity: 0.219 | ffnn:  3200 | (seqlen: 384, 3200 :ncol/nrow)
# sparsity: 0.211 | ffnn:  3232 | (seqlen: 384, 3232 :ncol/nrow)
# sparsity: 0.203 | ffnn:  3264 | (seqlen: 384, 3264 :ncol/nrow)
# sparsity: 0.195 | ffnn:  3296 | (seqlen: 384, 3296 :ncol/nrow)
# sparsity: 0.188 | ffnn:  3328 | (seqlen: 384, 3328 :ncol/nrow)
# sparsity: 0.180 | ffnn:  3360 | (seqlen: 384, 3360 :ncol/nrow)
# sparsity: 0.172 | ffnn:  3392 | (seqlen: 384, 3392 :ncol/nrow)
# sparsity: 0.164 | ffnn:  3424 | (seqlen: 384, 3424 :ncol/nrow)
# sparsity: 0.156 | ffnn:  3456 | (seqlen: 384, 3456 :ncol/nrow)
# sparsity: 0.148 | ffnn:  3488 | (seqlen: 384, 3488 :ncol/nrow)
# sparsity: 0.141 | ffnn:  3520 | (seqlen: 384, 3520 :ncol/nrow)
# sparsity: 0.133 | ffnn:  3552 | (seqlen: 384, 3552 :ncol/nrow)
# sparsity: 0.125 | ffnn:  3584 | (seqlen: 384, 3584 :ncol/nrow)
# sparsity: 0.117 | ffnn:  3616 | (seqlen: 384, 3616 :ncol/nrow)
# sparsity: 0.109 | ffnn:  3648 | (seqlen: 384, 3648 :ncol/nrow)
# sparsity: 0.102 | ffnn:  3680 | (seqlen: 384, 3680 :ncol/nrow)
# sparsity: 0.094 | ffnn:  3712 | (seqlen: 384, 3712 :ncol/nrow)
# sparsity: 0.086 | ffnn:  3744 | (seqlen: 384, 3744 :ncol/nrow)
# sparsity: 0.078 | ffnn:  3776 | (seqlen: 384, 3776 :ncol/nrow)
# sparsity: 0.070 | ffnn:  3808 | (seqlen: 384, 3808 :ncol/nrow)
# sparsity: 0.062 | ffnn:  3840 | (seqlen: 384, 3840 :ncol/nrow)
# sparsity: 0.055 | ffnn:  3872 | (seqlen: 384, 3872 :ncol/nrow)
# sparsity: 0.047 | ffnn:  3904 | (seqlen: 384, 3904 :ncol/nrow)
# sparsity: 0.039 | ffnn:  3936 | (seqlen: 384, 3936 :ncol/nrow)
# sparsity: 0.031 | ffnn:  3968 | (seqlen: 384, 3968 :ncol/nrow)
# sparsity: 0.023 | ffnn:  4000 | (seqlen: 384, 4000 :ncol/nrow)
# sparsity: 0.016 | ffnn:  4032 | (seqlen: 384, 4032 :ncol/nrow)
# sparsity: 0.008 | ffnn:  4064 | (seqlen: 384, 4064 :ncol/nrow)
# sparsity: 0.000 | ffnn:  4096 | (seqlen: 384, 4096 :ncol/nrow)
